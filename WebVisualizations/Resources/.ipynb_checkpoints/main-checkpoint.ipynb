# %% [markdown]
# # Analysis
#
# ## Three Observations:
#     *There is a clear correlation between temperature and latitude. Given that the analysis was done in December, the cities with northern latitudes have colder temperatures, whereas cities with southern latitudes have higher temperature.
#     *No correlation was found between humidity and latitude
#     *No correlation was found between cloudiness and latitude

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import pytemperature
import itertools
from scipy.stats import linregress


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "..Resources/cities.csv"

# Range of latitudes and longitudes. Create three buckets of latitudes to ensure samples 
# are representative of the entire world

lat_ranges = [(-90,-30),(-30,30),(30,90)]
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lats = []
lngs = []

cities = []

# Create a set of random lat and lng combinations
for lat_range in lat_ranges:
    lats = []
    lngs = []
    lat_range_count=len(cities)
    lats_rnd = np.random.uniform(low=lat_range[0], high=lat_range[1], size=600)
    lngs_rnd= np.random.uniform(low=-180.000, high=180.000, size=600)
    
    lats.append(lats_rnd)
    lngs.append(lngs_rnd)
    lat_lngs=zip(lats[0], lngs[0])
    
    for lat_lng in lat_lngs:
        city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
        if city not in cities:
            cities.append(city)
   
   
    lat_range_count=len(cities)-lat_range_count
    
    
    print(f"Total cities in latitude range {lat_range}: {lat_range_count}")

print(f"Total cities: {len(cities)}")
# Out:
# Total cities in latitude range (-90, -30): 86
# Total cities in latitude range (-30, 30): 319
# Total cities in latitude range (30, 90): 283
# Total cities: 688

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
weather_info=[]

for city in cities:
    query_url = url + "appid=" + api_key + "&q=" + city
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    try:
        name = weather_json['name']
        cloudiness = weather_json['clouds']['all']
        country = weather_json['sys']['country']
        date = weather_json['dt']
        humidity = weather_json['main']['humidity']
        lat = weather_json['coord']['lat']
        lng = weather_json['coord']['lon']
        max_temp = weather_json['main']['temp_max']
        wind_speed = weather_json['wind']['speed']
        print(f"Processing | {weather_json['name']}")
    
        weather_info.append({"City": name,
                             "Cloudiness": cloudiness,
                             "Country": country,
                             "Date": date,
                             "Humidity": humidity,
                             "Lat": lat,
                             "Lng": lng,
                             "Max Temp": max_temp,
                             "Wind Speed": wind_speed})
    
    except KeyError:
        print("City not found. Skipping...")
# Out:
# Processing | Te Anau
# Processing | Busselton
# Processing | Port Alfred
# Processing | Bluff
# Processing | New Norfolk
# Processing | Ushuaia
# Processing | Kruisfontein
# City not found. Skipping...
# Processing | Hobart
# Processing | Hermanus
# Processing | Mataura
# Processing | Mar del Plata
# Processing | Rikitea
# Processing | Punta Arenas
# Processing | Ulladulla
# Processing | Cape Town
# Processing | Waipawa
# Processing | Saint-Philippe
# City not found. Skipping...
# Processing | Castro
# Processing | Avarua
# Processing | Bredasdorp
# Processing | Mahebourg
# Processing | Margate
# City not found. Skipping...
# Processing | Vaini
# Processing | Lebu
# Processing | Albany
# Processing | Jamestown
# Processing | Westport
# Processing | Bambous Virieux
# Processing | Port Elizabeth
# Processing | Wyndham
# Processing | Cidreira
# Processing | Luderitz
# Processing | Melo
# Processing | Christchurch
# Processing | Saldanha
# Processing | Calbuco
# Processing | Methven
# Processing | Necochea
# Processing | Arraial do Cabo
# Processing | East London
# Processing | Burnie
# Processing | Constitucion
# Processing | Chui
# Processing | Rocha
# Processing | Port Lincoln
# Processing | Laguna
# Processing | Chivilcoy
# Processing | Beloha
# Processing | Ahipara
# Processing | Esperance
# Processing | Perth
# Processing | Rio Grande
# Processing | Portland
# Processing | Souillac
# Processing | Wanaka
# Processing | Rawson
# Processing | Whitianga
# Processing | Ancud
# Processing | Tuatapere
# Processing | Bairnsdale
# Processing | Kaitangata
# Processing | Tres Arroyos
# Processing | Cowra
# Processing | Singleton
# Processing | Dunedin
# Processing | Batemans Bay
# Processing | Carnarvon
# Processing | Plettenberg Bay
# Processing | Comodoro Rivadavia
# Processing | Vao
# Processing | Mount Gambier
# Processing | Kokstad
# Processing | Flinders
# Processing | Avera
# Processing | Coyhaique
# Processing | Port Shepstone
# Processing | Mudgee
# Processing | Richards Bay
# Processing | Coquimbo
# Processing | Rio Cuarto
# Processing | Imbituba
# Processing | Gualeguay
# Processing | Viedma
# Processing | San Patricio
# Processing | Mossamedes
# Processing | Hambantota
# Processing | Hasaki
# Processing | Peruibe
# Processing | Kupang
# Processing | Maun
# City not found. Skipping...
# Processing | Faanui
# Processing | Boa Vista
# Processing | Codrington
# Processing | Quzhou
# City not found. Skipping...
# Processing | Hilo
# Processing | Seminole
# Processing | Shingu
# Processing | Itaituba
# Processing | George Town
# Processing | Bowen
# Processing | Juba
# Processing | Port Hedland
# Processing | Atuona
# Processing | Betanzos
# Processing | Kapaa
# Processing | Hithadhoo
# City not found. Skipping...
# Processing | Banyo
# Processing | Morgan City
# Processing | Jacmel
# Processing | Tadine
# Processing | Rome
# City not found. Skipping...
# Processing | Hualmay
# Processing | Caucaia
# City not found. Skipping...
# Processing | Butaritari
# Processing | Bundaberg
# Processing | Thap Than
# City not found. Skipping...
# Processing | Coahuayana Viejo
# Processing | Ocosingo
# Processing | Kieta
# Processing | Faya
# Processing | Sakakah
# Processing | Owando
# Processing | Guiratinga
# Processing | Thinadhoo
# Processing | Cabo San Lucas
# Processing | Mfou
# Processing | Adrar
# Processing | Puerto Ayora
# Processing | Makaha
# Processing | Rurrenabaque
# Processing | Katsuura
# Processing | Cockburn Town
# Processing | Vitoria da Conquista
# Processing | Poso
# Processing | Malakal
# Processing | Salalah
# Processing | Airai
# Processing | Hong Kong
# Processing | Pangai
# Processing | Clarence Town
# Processing | Busembatia
# Processing | Ponta do Sol
# Processing | Kloulklubed
# Processing | Sotik Post
# Processing | Latehar
# Processing | Koratla
# Processing | Caravelas
# Processing | Guerrero Negro
# Processing | Callaway
# Processing | Pisco
# Processing | The Valley
# Processing | Surabaya
# Processing | Batouri
# Processing | Jalu
# Processing | Jumla
# Processing | Iquitos
# Processing | Maltahohe
# Processing | Gurupi
# Processing | Anloga
# Processing | Belmonte
# Processing | Buala
# Processing | Manaure
# Processing | Bengkulu
# Processing | Byron Bay
# Processing | Khanbari
# Processing | Tocopilla
# Processing | Bose
# Processing | Ilhabela
# Processing | Mattru
# Processing | Kihei
# Processing | Ternate
# Processing | Alyangula
# Processing | Taoudenni
# Processing | Los Llanos de Aridane
# Processing | Tautira
# Processing | Itarema
# Processing | Marabu
# Processing | Yulara
# Processing | Kalemie
# Processing | La Asuncion
# Processing | Lompoc
# Processing | Ginda
# Processing | Tezu
# Processing | Gizo
# Processing | Faxinal
# City not found. Skipping...
# Processing | Amboasary
# City not found. Skipping...
# Processing | Boende
# Processing | Ribeira Grande
# Processing | Ratnagiri
# Processing | San Cristobal
# Processing | Kavieng
# Processing | Quatre Cocos
# Processing | Wattegama
# Processing | Pochutla
# Processing | Lahaina
# Processing | Pundaguitan
# Processing | Bereda
# Processing | Tual
# Processing | Sechura
# Processing | San Fernando del Valle de Catamarca
# Processing | Kutum
# Processing | Nhulunbuy
# Processing | San Quintin
# Processing | Pekan
# Processing | Puerto Escondido
# Processing | Salinopolis
# Processing | Tepezala
# Processing | Shakawe
# Processing | Howick
# Processing | Kathu
# Processing | Namatanai
# Processing | Fare
# Processing | Eydhafushi
# Processing | Castanos
# Processing | Kiunga
# Processing | Labuan
# Processing | Mitsamiouli
# Processing | Okakarara
# Processing | Kendari
# Processing | Mount Isa
# Processing | Najran
# City not found. Skipping...
# Processing | Palora
# Processing | Omboue
# Processing | Sinnamary
# Processing | Berbera
# Processing | Bathsheba
# Processing | Ambanja
# Processing | Narasannapeta
# Processing | Gabu
# Processing | Cerrito
# Processing | San Juan de Abajo
# Processing | Muli
# Processing | Maceio
# Processing | Wajir
# Processing | Saint George
# Processing | Celestun
# Processing | Bako
# City not found. Skipping...
# Processing | Isangel
# Processing | Leer
# City not found. Skipping...
# Processing | Alofi
# Processing | Praia
# Processing | Hukuntsi
# Processing | Neiafu
# Processing | Goma
# Processing | Port Augusta
# Processing | Kiryat Gat
# Processing | Grand Gaube
# City not found. Skipping...
# Processing | Gigmoto
# Processing | Kigonsera
# Processing | Makakilo City
# Processing | Ciudad Bolivar
# Processing | 'Ahuimanu
# Processing | Ciudad Lazaro Cardenas
# Processing | Requena
# Processing | Araouane
# Processing | Kalmunai
# Processing | Kawalu
# Processing | Walvis Bay
# Processing | Geraldton
# Processing | Nara
# City not found. Skipping...
# Processing | Quelimane
# Processing | Saint-Francois
# Processing | Northam
# Processing | Bom Jesus
# Processing | Wanlaweyn
# Processing | Shimoda
# City not found. Skipping...
# Processing | Chilca
# Processing | Barra do Bugres
# Processing | Manokwari
# Processing | Buenos Aires
# Processing | Majene
# Processing | Ribas do Rio Pardo
# Processing | Keetmanshoop
# Processing | Carazinho
# Processing | Samarai
# Processing | Sugod
# Processing | General Higinio Morinigo
# Processing | Sao Miguel do Araguaia
# Processing | Poum
# Processing | Tessalit
# Processing | Naushahro Firoz
# Processing | Chokwe
# Processing | Provincia di Mantova
# Processing | Esim
# Processing | Sehithwa
# Processing | Kenema
# Processing | Lagoa Formosa
# Processing | Luanda
# Processing | Veraval
# Processing | Labuhan
# Processing | Sayyan
# Processing | Ballitoville
# Processing | Acapulco de Juarez
# Processing | Tiarei
# Processing | Galle
# City not found. Skipping...
# Processing | Baikunthpur
# Processing | Phayao
# City not found. Skipping...
# Processing | Naifaru
# Processing | Madang
# Processing | Alugan
# Processing | Tomatlan
# Processing | Taltal
# City not found. Skipping...
# Processing | Tekkali
# Processing | Vredefort
# Processing | Sarangani
# Processing | Yuancheng
# Processing | Bang Saphan
# City not found. Skipping...
# Processing | Santa Isabel do Rio Negro
# Processing | Boca do Acre
# City not found. Skipping...
# City not found. Skipping...
# Processing | Ishigaki
# Processing | Marawi
# Processing | Gobabis
# Processing | Lorengau
# City not found. Skipping...
# Processing | Chililabombwe
# Processing | Isla Mujeres
# Processing | Ugoofaaru
# Processing | Alta Floresta
# Processing | Coxim
# Processing | Cavalcante
# Processing | Bethanien
# Processing | West Bay
# Processing | Atar
# Processing | Huarmey
# Processing | Bandarbeyla
# Processing | Kidal
# Processing | Uyuni
# Processing | Mapastepec
# Processing | Naze
# Processing | Matara
# Processing | Kirakira
# Processing | Lingao
# Processing | San Buenaventura
# Processing | Gijang
# Processing | Kendal
# Processing | Puerto Leguizamo
# Processing | Rey Bouba
# Processing | Ampanihy
# Processing | Arrecife
# Processing | Kedougou
# Processing | Matadi
# Processing | Barcelos
# Processing | Half Moon Bay
# Processing | Gorontalo
# Processing | Mahasamund
# Processing | Guadalupe
# Processing | Nouadhibou
# Processing | Laem Sing
# Processing | Puerto Baquerizo Moreno
# Processing | Mogadishu
# Processing | Jijiga
# Processing | Djibo
# City not found. Skipping...
# Processing | Aquiraz
# Processing | Ouallam
# Processing | Kuliyapitiya
# Processing | Lavumisa
# Processing | Meulaboh
# Processing | Sassandra
# Processing | Paredon
# Processing | Kahului
# Processing | Bilma
# Processing | Sao Luis
# Processing | Tshane
# Processing | Ingham
# Processing | Garoowe
# Processing | Maragogi
# Processing | Sao Filipe
# Processing | Lethem
# Processing | Navrongo
# Processing | Padang
# Processing | Savelugu
# Processing | Pyapon
# Processing | Kununurra
# Processing | Nalut
# Processing | Chibombo
# Processing | Mahajanga
# Processing | Daniel Flores
# City not found. Skipping...
# City not found. Skipping...
# Processing | Mancora
# City not found. Skipping...
# Processing | Ulaanbaatar
# Processing | Tasiilaq
# Processing | Aklavik
# Processing | Saskylakh
# Processing | Arrondissement de Gap
# Processing | Raudeberg
# Processing | Petropavlovsk-Kamchatsky
# Processing | Barrow
# City not found. Skipping...
# Processing | Kumul
# Processing | Dikson
# Processing | Sioux Lookout
# Processing | North Bend
# Processing | Kodiak
# Processing | Pevek
# Processing | Hofn
# Processing | Severo-Kuril'sk
# City not found. Skipping...
# Processing | Yellowknife
# Processing | Laas
# City not found. Skipping...
# Processing | Verkhoyansk
# Processing | Quincy
# Processing | Chokurdakh
# City not found. Skipping...
# Processing | Siemiatycze
# Processing | Qaanaaq
# Processing | Tura
# Processing | Yar-Sale
# Processing | Magadan
# Processing | Krasnosel'kup
# Processing | Ilulissat
# Processing | Banff
# Processing | Dubuque
# Processing | Lappeenranta
# Processing | Navoiy
# City not found. Skipping...
# Processing | Gornopravdinsk
# Processing | Brandon
# City not found. Skipping...
# Processing | La Tuque
# Processing | Anadyr
# Processing | Udachny
# City not found. Skipping...
# Processing | Tiksi
# Processing | Farmington
# Processing | Khatanga
# Processing | Kamenka
# Processing | Baykit
# Processing | Morristown
# Processing | Saint-Leonard
# Processing | Thompson
# Processing | Plouzane
# Processing | Ust-Kuyga
# Processing | Jimo
# Processing | Roald
# City not found. Skipping...
# Processing | Tromso
# Processing | Altay
# Processing | Salym
# Processing | Berlevag
# Processing | Yining
# Processing | Novobirilyussy
# City not found. Skipping...
# Processing | Cervo
# Processing | Tuktoyaktuk
# Processing | Urumqi
# Processing | Iqaluit
# Processing | Kozmodemyansk
# Processing | Vrangel
# Processing | Verkhnevilyuysk
# Processing | Bulgan
# Processing | Bethel
# Processing | Nikolskoye
# Processing | Ayan
# Processing | Haines Junction
# Processing | Karpathos
# Processing | Sitka
# City not found. Skipping...
# City not found. Skipping...
# Processing | Ushibukamachi
# Processing | Petrovsk-Zabaykal'skiy
# Processing | Kurumkan
# Processing | Svetlaya
# Processing | Pacific Grove
# Processing | Torbay
# Processing | Upernavik
# Processing | Alpena
# Processing | Nanao
# Processing | Kajaani
# City not found. Skipping...
# Processing | Alihe
# Processing | Dengzhou
# Processing | Sidi Ali
# Processing | Zeya
# Processing | West Wendover
# City not found. Skipping...
# Processing | Pecos
# Processing | Firozpur
# Processing | Havre-Saint-Pierre
# Processing | Antropovo
# Processing | Narsaq
# Processing | Brae
# Processing | Hinton
# Processing | Saint Simons
# Processing | Longyearbyen
# Processing | Plerin
# Processing | Ostrovnoy
# Processing | Provideniya
# Processing | Athabasca
# Processing | Polis
# Processing | Rezh
# Processing | Vostok
# Processing | Morro Bay
# Processing | Rokytne
# Processing | Pavilosta
# Processing | Kangaatsiaq
# Processing | Kirkwall
# Processing | Nyurba
# Processing | Pangnirtung
# City not found. Skipping...
# Processing | Fort-Shevchenko
# Processing | Ukiah
# Processing | Tilichiki
# Processing | Laiyang
# Processing | Ust'-Omchug
# Processing | Klaksvik
# Processing | Tutayev
# Processing | Leningradskiy
# Processing | Norman Wells
# Processing | Yumen
# Processing | Staraya Poltavka
# Processing | Beyneu
# City not found. Skipping...
# Processing | Vila Franca do Campo
# City not found. Skipping...
# Processing | Fortuna
# Processing | Nanortalik
# Processing | Praia da Vitoria
# Processing | High Prairie
# Processing | Kenai
# Processing | Fairbanks
# Processing | Kholm
# Processing | Novikovo
# Processing | Ashquelon
# City not found. Skipping...
# Processing | Paamiut
# Processing | Hazorasp
# Processing | Nur
# Processing | Susa
# Processing | Provincia de Ciudad Real
# Processing | Storslett
# Processing | Lagoa
# Processing | Klyuchi
# Processing | Bellmead
# Processing | North Platte
# Processing | Boden
# Processing | Lourdes
# Processing | Tank
# Processing | Husavik
# Processing | Qaqortoq
# Processing | Ozernovskiy
# Processing | Rovaniemi
# Processing | Dingle
# Processing | Shasta Lake
# Processing | Corum
# Processing | Mitchell
# Processing | Gazli
# Processing | Vestmannaeyjar
# Processing | Ola
# Processing | Brest
# Processing | Ossora
# City not found. Skipping...
# Processing | Zhicheng
# Processing | Deloraine
# Processing | Nerchinskiy Zavod
# Processing | Maniitsoq
# Processing | Anchorage
# Processing | Salyan
# Processing | Moose Factory
# Processing | Lavrentiya
# Processing | Vardo
# Processing | Folldal
# Processing | Clyde River
# Processing | Zatoka
# Processing | Lebork
# Processing | Preobrazheniye
# Processing | Letka
# Processing | Kushiro
# Processing | Lewiston
# Processing | Sakaiminato
# Processing | Jiuquan
# Processing | Aldan
# City not found. Skipping...
# Processing | Carroll
# Processing | Derzhavinsk
# Processing | Elko
# Processing | Vaasa
# Processing | Chapais
# Processing | Erzin
# Processing | Nome
# Processing | At-Bashi
# Processing | Kamaishi
# Processing | Sernur
# Processing | Marrakesh
# Processing | Hamilton
# Processing | Safi
# Processing | Aksha
# Processing | Grande Prairie
# Processing | Shelburne
# Processing | Plastun
# Processing | Den Helder
# Processing | Storforshei
# Processing | Nantucket
# Processing | Strezhevoy
# City not found. Skipping...
# Processing | Fort Morgan
# City not found. Skipping...
# Processing | Kosh-Agach
# Processing | Saint Anthony
# Processing | Peniche
# City not found. Skipping...
# Processing | Oksfjord
# Processing | Altoona
# Processing | Miyazu
# Processing | Big Spring
# Processing | Cherskiy
# Processing | Shar
# Processing | Severomuysk
# Processing | La Ronge
# Processing | Cicevac
# Processing | Oskemen
# Processing | Zakamensk
# Processing | Srednekolymsk
# Processing | Noyabrsk
# Processing | Ringe
# Processing | Coos Bay
# Processing | Leshukonskoye
# Processing | Okhotsk
# City not found. Skipping...
# Processing | Talnakh
# Processing | Dudinka
# Processing | Minsk
# City not found. Skipping...
# Processing | Villena
# Processing | Belaya Gora
# Processing | Khovd
# Processing | Yangi Marg`ilon
# Processing | Karaj
# Processing | Ajdabiya
# Processing | Vuktyl
# Processing | Yagodnoye
# Processing | Virginia Beach
# Processing | Dryden
# Processing | Chernyshevskiy
# City not found. Skipping...
# Processing | Nynaeshamn
# Processing | Dalton
# Processing | Vilyuysk
# Processing | Tarko-Sale
# Processing | Annan
# Processing | Honningsvag
# Processing | Kayerkan
# City not found. Skipping...
# Processing | Lixouri
# Processing | Oktyabrskiy
# Processing | Hirado
# Processing | Changji
# Processing | Fort Nelson
# City not found. Skipping...
# Processing | Camacha
# City not found. Skipping...
# Processing | Erzincan
# Processing | Qingdao
# Processing | Sobolevo
# Processing | Chara
# Processing | Tsivilsk
# Processing | Benghazi
# City not found. Skipping...
# Processing | Erenhot
# Processing | Mago
# Processing | Liberal
# City not found. Skipping...

# %%
weather_data=pd.DataFrame(weather_info)

# %%
#Convert temperature from Kelvin to F

weather_data['Max Temp']=weather_data['Max Temp'].apply(lambda x: pytemperature.k2f(x))

# %%
weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Te Anau          88      NZ  1581631659        85 -45.42  167.72
# 1    Busselton          14      AU  1581631659        54 -33.65  115.33
# 2  Port Alfred          34      ZA  1581631659        97 -33.59   26.89
# 3        Bluff          95      NZ  1581631660        72 -46.60  168.33
# 4  New Norfolk          75      AU  1581631660        82 -42.78  147.06
#
#    Max Temp  Wind Speed
# 0     48.47        1.38
# 1     67.98        5.76
# 2     67.98        1.79
# 3     54.98        2.24
# 4     64.97        3.10

# %%
#Etracting fields to be plotted from dataframe 

lats = weather_data["Lat"]
max_temps = weather_data["Max Temp"]
humidity = weather_data["Humidity"]
cloudiness = weather_data["Cloudiness"]
wind_speed = weather_data["Wind Speed"]

# %%
#Export to csv
weather_data.to_csv(output_data_file, index_label="City_ID")

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 9 columns):
# City          630 non-null object
# Cloudiness    630 non-null int64
# Country       630 non-null object
# Date          630 non-null int64
# Humidity      630 non-null int64
# Lat           630 non-null float64
# Lng           630 non-null float64
# Max Temp      630 non-null float64
# Wind Speed    630 non-null float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 44.4+ KB

# %%
#Latitude vs. Temperature Plot

# %%
plt.scatter(lats, max_temps, marker='o', edgecolor='black', alpha=0.75)
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlim((weather_data['Lat'].min()*1.15), (weather_data['Lat'].max()*1.15))
plt.ylim((weather_data['Max Temp'].min()*1.15), (weather_data['Max Temp'].max()*1.15))
plt.grid(True)

plt.savefig("../assets/Fig1.png")

plt.show()

# %%
#Latitude vs. Humidity Plot

# %%
plt.scatter(lats, humidity, marker='o', edgecolors='black', alpha=0.75)
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.xlim((weather_data['Lat'].min()*1.15), (weather_data['Lat'].max()*1.15))
plt.ylim(-10, 110)

plt.grid(True)

plt.savefig("../assets/Fig2.png")

plt.show()

# %%
#Latitude vs. Cloudiness Plot

# %%
plt.scatter(lats, cloudiness, marker='o', edgecolors='black', alpha=0.75)
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlim((weather_data['Lat'].min()*1.15), (weather_data['Lat'].max()*1.15))
plt.ylim(-10, 110)

plt.grid(True)

plt.savefig("../assets/Fig3.png")

plt.show()

# %%
#Latitude vs. Windspeed

# %%
plt.scatter(lats, wind_speed, marker='o', edgecolors='black', alpha=0.75)
plt.title("City Latitude vs. Windspeed (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Windspeed (mph)")

plt.grid(True)

plt.savefig("../assets/Fig4.png")

plt.show()

# %%
#remove non relevent columns from dataframe to display on website
df = weather_data[['City','Country','Lat','Lng','Max Temp','Cloudiness', 'Humidity','Wind Speed']]
df.head()
# Out:
#           City Country    Lat     Lng  Max Temp  Cloudiness  Humidity  \
# 0      Te Anau      NZ -45.42  167.72     48.47          88        85
# 1    Busselton      AU -33.65  115.33     67.98          14        54
# 2  Port Alfred      ZA -33.59   26.89     67.98          34        97
# 3        Bluff      NZ -46.60  168.33     54.98          95        72
# 4  New Norfolk      AU -42.78  147.06     64.97          75        82
#
#    Wind Speed
# 0        1.38
# 1        5.76
# 2        1.79
# 3        2.24
# 4        3.10

# %%
df.to_csv(output_data_file, index_label='City_ID')

# %%
html=df.to_html()

text_file = open("data_output.html", "w")
text_file.write(html)
text_file.close()

# %%
#Linear Regression

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create seperate dataframes for Northern and Southern hemisphere
northern_hemi_df = df.loc[(df["Lat"] >= 0)]
southern_hemi_df = df.loc[(df["Lat"] < 0)]

# %%
#Temp vs Lat
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-squared is: -0.861308366133035

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (-30,40))
# Out:
# The r-squared is: 0.5072684546665094

# %%
#Humidity vs Lat

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-squared is: 0.34972611878758875

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-30,150))
# Out:
# The r-squared is: 0.15547811292486838

# %%
##Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (40,10))
# Out:
# The r-squared is: 0.22255003470815393

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-30,30))
# Out:
# The r-squared is: 0.03272764694994678

# %%
#Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (40,25))
# Out:
# The r-squared is: 0.021583989793075617

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-30,30))
# Out:
# The r-squared is: -0.13520370125863562
